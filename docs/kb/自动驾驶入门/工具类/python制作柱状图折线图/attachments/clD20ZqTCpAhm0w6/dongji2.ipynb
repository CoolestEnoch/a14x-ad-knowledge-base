# %%
import numpy as np
import matplotlib.pyplot as plt
fig,ax=plt.subplots(figsize=(18, 10), dpi=100)
plt.rc('font',family='Times New Roman')
# 数据
# plt.ylim(0,10)

# scenes = ['70 scenes (0.1)','175 scenes (0.25)','700 scenes (full)']
'''
AP1 = [ 78.44, 57.01, 62.45, 80.80]
AP2 = [ 45.15, 44.87, 44.79, 46.74]
AP3 = [ 63.14, 58.69, 57.71, 64.59]
#AP3 = [ 63.14, 58.69, 47.71, 64.59]
AP4 = [ 63.14, 58.69, 57.71, 64.59]
AP5 = [ 63.14, 58.69, 57.71, 64.59]
AP6 = [ 63.14, 58.69, 57.71, 64.59]
'''

AP1 = [ 4.67587457, 1.98042234, 1.71031137] # 3D 框大小数据
AP2 = [ 6.79805322, 2.38702661, 2.68339468]
AP3 = [ 10.97861128,  2.93520475,  3.74245994]
AP4 = [ 1.83185034, 0.64898639, 1.38759864]
AP5 = [ 0.74271349, 0.69547458, 1.76109811]
AP6 = [ 0.44713195, 0.48103105, 0.78314877]
'''

AP1 = [ 0.07, 159.29] # 方差数据
AP2 = [ 0.11, 209.24]
AP3 = [ 0.21,  246.62]
AP4 = [ 0.21, 106.46]
AP5 = [ 0.16, 87.82]
AP6 = [ 0.10, 71.60]
'''
bar_width = 0.125
LineW =4
LineW_pianyi=0.012
x = np.arange(3)
# 绘图 x 表示 从那里开始

color1 = [179 / 255, 198 / 255, 230 / 255]
color2 = [248 / 255, 203 / 255, 170 / 255]
color3 = [255/ 255, 242/ 255, 204/ 255]
color4 = [213/ 255, 232/ 255, 212/ 255]
color5 = [248/ 255, 206/ 255, 204/ 255]
color6 = [225/ 255, 213/ 255, 231/ 255]
color1_edge = '#658cd1'
color2_edge = '#f07c32'
color3_edge = '#d6b656'
color4_edge = '#82B366'
color5_edge = '#B85450'
color6_edge = '#9673A6'

plt.bar(x, AP1, bar_width,color=color1, edgecolor=color1_edge, label="Car",align="center",linewidth=LineW)
plt.bar(x+1*(bar_width+LineW_pianyi), AP2, bar_width, color=color2, edgecolor=color2_edge, 
        align="center",label="Truck",linewidth=LineW)
plt.bar(x+2*(bar_width+LineW_pianyi), AP3, bar_width, color=color3, edgecolor=color3_edge, 
        align="center",label="Bus",linewidth=LineW)
plt.bar(x+3*(bar_width+LineW_pianyi), AP4, bar_width, color=color4, edgecolor=color4_edge, 
        align="center",label="Motor.",linewidth=LineW)
plt.bar(x+4*(bar_width+LineW_pianyi), AP5, bar_width, color=color5, edgecolor=color5_edge, 
        align="center",label="Ped.",linewidth=LineW)
plt.bar(x+5*(bar_width+LineW_pianyi), AP6, bar_width, color=color6, edgecolor=color6_edge, 
        align="center",label="T.C.",linewidth=LineW)
plt.rc('font',family='Times New Roman')
# 展示图片

plt.tick_params(axis='x', labelsize=40)
plt.tick_params(axis='y', labelsize=40)
plt.ylabel('Avg. 3D Box Size',fontsize=45)
plt.xlabel('(b) Mean of 3D box dimensions',fontsize=45)
plt.yticks([])
a = [(bar_width+LineW_pianyi)*2.5, (bar_width+LineW_pianyi)*2.5+1, (bar_width+LineW_pianyi)*2.5+2]
labels = ['Length','Width', 'Height']
b=np.arange(0,15,2)
plt.xticks(a,labels,rotation = 0,fontsize=40,font="Times New Roman")
plt.yticks(b,rotation = 90, fontsize=40,font="Times New Roman")
# plt.rcParams.update({'font.size': 40})
plt.legend(loc='upper right',ncol=2,fontsize=36,frameon=False,shadow=False,
           handlelength=0.7,columnspacing=0.5,
           prop={'family': 'Times New Roman'})

for x,y in zip(a, AP1):
#     print(x,y)
    plt.text(x-2.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')
for x,y in zip(a, AP2):
#     print(x,y)
    #plt.text(x-1.5*bar_width,y,y,ha="center", va="bottom", fontsize=13,rotation=360)
    plt.text(x-1.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')
for x,y in zip(a, AP3):
#     print(x,y)
    #plt.text(x-0.5*bar_width,y,y,ha="center", va="bottom", fontsize=13,rotation=360)
    plt.text(x-0.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')
for x,y in zip(a, AP4):
#     print(x,y)
    #plt.text(x+0.5*bar_width,y,y,ha="center", va="bottom", fontsize=15,rotation=360)
    plt.text(x+0.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')
for x,y in zip(a, AP5):
#     print(x,y)
    #plt.text(x+1.5*bar_width,y,y,ha="center", va="bottom", fontsize=15,rotation=360)
    plt.text(x+1.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')
for x,y in zip(a, AP6):
#     print(x,y)
    #plt.text(x+2.5*bar_width,y,y,ha="center", va="bottom", fontsize=15,rotation=360)
    plt.text(x+2.5*(bar_width+LineW_pianyi),y+0.3,f'{y:.2f}',ha="center", va="bottom", fontsize=32,rotation=90,weight='bold')

plt.savefig('./dongji_2.png',bbox_inches='tight')
plt.show()
